# %%
import pandas as pd

# Read the three files into python as dataframes.

data_1 = pd.read_csv ("/Users/noachmeged/Documents/Ironhack/Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv") 
data_2 = pd.read_csv ("/Users/noachmeged/Documents/Ironhack/Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv")
data_3 = pd.read_csv ("/Users/noachmeged/Documents/Ironhack/Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv")

# %%
# Show the DataFrame's shape.
data_1.shape

data_2.shape

data_3.shape
# Out:
# (7070, 11)

# %%
# Standardize the header names.
data_1.columns = data_1.columns.str.lower().str.replace(" ", "_")
data_2.columns = data_2.columns.str.lower().str.replace(" ", "_")
data_3.columns = data_3.columns.str.lower().str.replace(" ", "_")
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
# Rearrange the columns in the dataframe as needed
data_1.rename(columns={'st': 'state'}, inplace=True)
data_2.rename(columns={'st': 'state'}, inplace=True)

# %%
# Concatenate the three dataframes
data_concat = pd.concat([data_1,data_2,data_3]).reset_index(drop=True)
data_concat
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
# Which columns are numerical?
data_concat.dtypes 
# Based on the type and looking with the add functiom. I can tell that 
# number_of_open_complaints, customer_lifetime_value, income, monthy_premium_auto, total_claim_amount is numerical
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
#Which columns are categorical?
# gender, education,policy_type, vehicle_class
# Out:
# Object `categorical` not found.
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
# Understand the meaning of all columns
#customer                      costumer id
#state                         state of the costumer
#gender                        sex of the costumer
#education                     level of education
#customer_lifetime_value       Customer lifetime value is the total worth to a business of a customer over the whole period of their relationship with the brand.
#income                        Yearly income of costumers in dollars
#monthly_premium_auto          The premium is the amount of money paid by the policyholder to the insurance company in exchange for coverage.
#number_of_open_complaints     The number of complaints by the costumer
#policy_type                   If the costumer owns a corporate auto or personal auto
#vehicle_class                 If the costumers owns an personal or corporate auto
#total_claim_amount            The total amount of money the costumer claimed by the insurance

# %%
# Perform the data cleaning operations mentioned so far in class
#Delete the column education and the number of open complaints from the dataframe.
data_concat.drop(['education', 'number_of_open_complaints'], axis=1, inplace=True)

# %%
data_concat
# Out:
#       customer       state gender customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 
data_concat['customer_lifetime_value'] = data_concat['customer_lifetime_value'] * 100

data_concat
# Out:
#       customer       state gender  customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                      NaN      0.0
# 2      AI49188      Nevada      F                      NaN  48767.0
# 3      WW63253  California      M                      NaN      0.0
# 4      GA49547  Washington      M                      NaN  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+10  71941.0
# 12070  PK87824  California      F             3.096511e+09  21604.0
# 12071  TD14365  California      M             8.163890e+09      0.0
# 12072  UP19263  California      M             7.524442e+09  21941.0
# 12073  Y167826  California      M             2.611837e+09      0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# ...

# %%
# Change dtype to numerical type.
data_concat['customer_lifetime_value'] = pd.to_numeric(data_concat['customer_lifetime_value'], errors='coerce')

data_concat.dtypes
# Out:
# customer                    object
# state                       object
# gender                      object
# customer_lifetime_value    float64
# income                     float64
# monthly_premium_auto       float64
# policy_type                 object
# vehicle_class               object
# total_claim_amount         float64
# dtype: object

# %%
# Check for duplicate rows in the data and remove if any.
data_concat = data_concat.drop_duplicates()
data_concat
# Out:
#       customer       state gender  customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                      NaN      0.0
# 2      AI49188      Nevada      F                      NaN  48767.0
# 3      WW63253  California      M                      NaN      0.0
# 4      GA49547  Washington      M                      NaN  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+10  71941.0
# 12070  PK87824  California      F             3.096511e+09  21604.0
# 12071  TD14365  California      M             8.163890e+09      0.0
# 12072  UP19263  California      M             7.524442e+09  21941.0
# 12073  Y167826  California      M             2.611837e+09      0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# ...

# %%
# Filter out the data for customers who have an income of 0 or less.
data_concat = data_concat[data_concat['income'] <= 0]
data_concat
# Out:
#       customer       state gender  customer_lifetime_value  income  \
# 0      RB50392  Washington    NaN                      NaN     0.0
# 1      QZ44356     Arizona      F                      NaN     0.0
# 3      WW63253  California      M                      NaN     0.0
# 7      CF85061     Arizona      M                      NaN     0.0
# 10     SX51350  California      M                      NaN     0.0
# ...        ...         ...    ...                      ...     ...
# 12063  WZ45103  California      F             5.678050e+09     0.0
# 12065  RX91025  California      M             1.987226e+10     0.0
# 12066  AC13887  California      M             4.628995e+09     0.0
# 12071  TD14365  California      M             8.163890e+09     0.0
# 12073  Y167826  California      M             2.611837e+09     0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...
